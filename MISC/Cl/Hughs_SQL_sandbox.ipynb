# %%
import pandas as pd
import numpy as np
import pymysql 
import sqlalchemy

# %%
# import the SQLAlchemy libraries
from sqlalchemy import create_engine

# create the connection string to the MySQL database
engine = create_engine('mysql+pymysql://ucfnjma:jucahedagu@dev.spatialdatacapture.org:3306/ucfnjma')

# make the connection to the database
conn = engine.raw_connection()

# %%
#test engine
engine
# Out:
# Engine(mysql+pymysql://ucfnjma:***@dev.spatialdatacapture.org:3306/ucfnjma)

# %%
#test connection
conn

# %%
table_names = engine.table_names()
print(table_names)
# Out:
# ['Cluster_Chart', 'Cluster_Data', 'Cluster_Labels', 'Cluster_Output', 'Cluster_keys', 'Country_Per_Cluster', 'MetCountry(clustered)', 'donation_data', 'z_Clustet_Table', 'z_Final_Data', 'z_Fri_Final_Data', 'z_METDataClean', 'z_MET_Final', 'z_MET_Final2', 'z_MET_USA_clean_spatial4', 'z_Met430k', 'z_Met_noUSA', 'z_SpatialMET', 'z_SpatialMET_test', 'z_artwork_cities', 'z_artwork_cities_final', 'z_cities', 'z_countries', 'z_countries_donation', 'z_countries_for_join', 'z_countries_years', 'z_countries_years_good', 'z_final_donation', 'z_materials', 'z_metadata', 'z_pre_tues_Final_Data', 'z_table_donation', 'z_table_donation_good', 'z_worldCities', 'z_years']

# %%
########
# To upload a dataframe
#########


#Change fileName with the .csv file you want to read into python
# in the right directory
df = pd.read_csv('Tuesday_Data.csv')
df.replace(r'\s+', np.nan, regex=True)

#Change SQL_Table_Name for the name of your newly created table
# Out:
# C:\Users\Hugh\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Object ID artist_nationality  object_begin_date  object_end_date  \
# 0               1           American               1853             1853
# 1              12           American               1876             1876
# 2              15                NaN               1665             1700
# 3              16                NaN               1800             1900
# 4              17                NaN               1867             1867
# 5              18                NaN               1860             1860
# 6              19                NaN               1859             1859
# 7              20                NaN               1860             1860
# 8              21                NaN               1859             1859
# 9              22                NaN               1881             1881
# 10             23                NaN               1878             1878
# 11             24                NaN               1860             1870
# 12             25                NaN               1860             1870
# 13             26                NaN               1860             1870
# 14             27                NaN               1860             1870
# 15             28                NaN               1860             1870
# 16             29                NaN               1860             1870
# 17             30                NaN               1885             1885
# 18             31                NaN               1885             1885
# 19             32                NaN               1866             1866
# 20             33           American               1876             1876
# 21             34                NaN               1847             1850
# 22             35                NaN               1893             1895
# 23             36                NaN               1884             1887
# 24             37             French               1782             1785
# 25             38             French               1782             1785
# 26             39                NaN               1770             1800
# 27             40                NaN               1830             1870
# 28             41           American               1850             1870
# 29             42                NaN               1795             1810
# ...           ...                ...                ...              ...
# 427562     825635                NaN               1821             1900
# 427563     825646                NaN               1860             1860
# 427564     825676                NaN               1886             1886
# 427565     825677                NaN               1826             1836
# 427566     825678                NaN               1875             1885
# 427567     825679                NaN               1830             1850
# 427568     825680                NaN               1875             1885
# 427569     825681                NaN               1821             1900
# 427570     825682                NaN               1880             1880
# 427571     825684                NaN               1838             1893
# 427572     825685                NaN               1875             1885
# 427573     825728                NaN               1800             1900
# 427574     825729                NaN               1878             1878
# 427575     825730                NaN               1875             1885
# 427576     825731                NaN               1873             1873
# 427577     825732                NaN               1793             1800
# 427578     825733                NaN               1875             1885
# 427579     825735                NaN               1830             1870
# 427580     825736                NaN               1830             1870
# 427581     825737                NaN               1796             1796
# 427582     825738                NaN               1830             1870
# 427583     825739                NaN               1830             1870
# 427584     825740                NaN               1830             1870
# 427585     825741                NaN               1830             1870
# 427586     825742                NaN               1830             1870
# 427587     825743                NaN               1830             1870
# 427588     825745                NaN               1830             1870
# 427589     825746                NaN               1794             1794
# 427590     825747                NaN               1796             1796
# 427591     825751                NaN              -1600            -1050
#
#        credit_line    country   classification onclear_medium  \
# 0              NaN        NaN            Metal           Gold
# 1              NaN        NaN            Metal           Gold
# 2              NaN     Mexico           Silver         Silver
# 3              NaN     Mexico            Metal            NaN
# 4              NaN     Mexico            Metal            NaN
# 5              NaN     Mexico            Metal            NaN
# 6              NaN     Mexico            Metal            NaN
# 7              NaN     Mexico            Metal            NaN
# 8              NaN     Mexico            Metal            NaN
# 9              NaN  Guatemala           Silver         Silver
# 10             NaN  Guatemala           Silver         Silver
# 11             NaN     Mexico            Metal         Nickel
# 12             NaN     Mexico            Metal         Nickel
# 13             NaN     Mexico            Metal         Nickel
# 14             NaN     Mexico            Metal         Nickel
# 15             NaN     Mexico            Metal         Nickel
# 16             NaN     Mexico            Metal         Nickel
# 17             NaN     Mexico            Metal         Nickel
# 18             NaN     Mexico            Metal         Nickel
# 19             NaN     Mexico            Metal           Gold
# 20             NaN        NaN            Glass            NaN
# 21             NaN        NaN        Furniture            NaN
# 22             NaN        NaN            Metal            NaN
# 23             NaN        NaN        Furniture            NaN
# 24             NaN        NaN         Ceramics            NaN
# 25             NaN        NaN         Ceramics            NaN
# 26             NaN        NaN              NaN          Paper
# 27             NaN        NaN            Glass            NaN
# 28             NaN        NaN            Glass            NaN
# 29             NaN        NaN            Metal            NaN
# ...            ...        ...              ...            ...
# 427562         NaN     France           Prints     Lithograph
# 427563         NaN        NaN           Prints        Etching
# 427564         NaN        NaN           Prints        Etching
# 427565         NaN        NaN           Prints     Lithograph
# 427566         NaN        NaN           Prints        Etching
# 427567         NaN     France           Prints      Engraving
# 427568         NaN        NaN           Prints        Etching
# 427569         NaN     France           Prints      Engraving
# 427570         NaN        NaN           Prints        Etching
# 427571         NaN     France           Prints            NaN
# 427572         NaN        NaN           Prints            NaN
# 427573         NaN     France           Prints            NaN
# 427574         NaN        NaN           Prints        Etching
# 427575         NaN        NaN           Prints        Etching
# 427576         NaN        NaN           Prints        Etching
# 427577         NaN     France           Prints            NaN
# 427578         NaN        NaN           Prints        Etching
# 427579         NaN        NaN              NaN            NaN
# 427580         NaN        NaN              NaN            NaN
# 427581         NaN     France           Prints            NaN
# 427582         NaN        NaN              NaN            NaN
# 427583         NaN        NaN              NaN            NaN
# 427584         NaN        NaN              NaN            NaN
# 427585         NaN        NaN              NaN            NaN
# 427586         NaN        NaN              NaN            NaN
# 427587         NaN        NaN              NaN            NaN
# 427588         NaN        NaN              NaN            NaN
# 427589         NaN        NaN  Prints|Ephemera        Etching
# 427590         NaN        NaN  Prints|Ephemera        Etching
# 427591         NaN     Cyprus              NaN           Gold
#
#        artist_display_name artist_display_bio     culture    object_name  \
# 0                      NaN           American         NaN           Coin
# 1                      NaN           American         NaN           Coin
# 2                      NaN                NaN     Mexican           Coin
# 3                      NaN                NaN     Mexican           Peso
# 4                      NaN                NaN     Mexican           Peso
# 5                      NaN                NaN     Mexican           Peso
# 6                      NaN                NaN     Mexican           Peso
# 7                      NaN                NaN     Mexican           Peso
# 8                      NaN                NaN     Mexican           Peso
# 9                      NaN                NaN  Guatemalan           Coin
# 10                     NaN                NaN  Guatemalan           Coin
# 11                     NaN                NaN     Mexican       Centavos
# 12                     NaN                NaN     Mexican       Centavos
# 13                     NaN                NaN     Mexican       Centavos
# 14                     NaN                NaN     Mexican       Centavos
# 15                     NaN                NaN     Mexican       Centavos
# 16                     NaN                NaN     Mexican       Centavos
# 17                     NaN                NaN     Mexican       Centavos
# 18                     NaN                NaN     Mexican       Centavos
# 19                     NaN                NaN     Mexican          Pesos
# 20                     NaN           American    American           Bust
# 21                     NaN          1835–1853    American          Clock
# 22                     NaN          1859–1927    American           Vase
# 23                     NaN                NaN    American            NaN
# 24                     NaN             French     British         Figure
# 25                     NaN             French     British         Figure
# 26                     NaN                NaN    American  Advertisement
# 27                     NaN           American    American            NaN
# 28                     NaN           American    American            NaN
# 29                     NaN                NaN    American        Andiron
# ...                    ...                ...         ...            ...
# 427562                 NaN             French         NaN          Print
# 427563                 NaN           American         NaN          Print
# 427564                 NaN           American         NaN          Print
# 427565                 NaN            British         NaN          Print
# 427566                 NaN           American         NaN          Print
# 427567                 NaN             French         NaN          Print
# 427568                 NaN           American         NaN          Print
# 427569                 NaN             French         NaN          Print
# 427570                 NaN           American         NaN          Print
# 427571                 NaN             French         NaN          Print
# 427572                 NaN           American         NaN          Print
# 427573                 NaN             French         NaN          Print
# 427574                 NaN           American         NaN          Print
# 427575                 NaN           American         NaN          Print
# 427576                 NaN           American         NaN          Print
# 427577                 NaN             French         NaN          Print
# 427578                 NaN           American         NaN          Print
# 427579                 NaN            British         NaN            NaN
# 427580                 NaN            British         NaN            NaN
# 427581                 NaN             French         NaN          Print
# 427582                 NaN            British         NaN            NaN
# 427583                 NaN            British         NaN            NaN
# 427584                 NaN            British         NaN            NaN
# 427585                 NaN            British         NaN            NaN
# 427586                 NaN            British         NaN            NaN
# 427587                 NaN            British         NaN            NaN
# 427588                 NaN            British         NaN            NaN
# 427589                 NaN            British         NaN            NaN
# 427590                 NaN           American         NaN            NaN
# 427591                 NaN                NaN     Cypriot        Roundel
#
#                                                      link  acq_year  \
# 0        http://www.metmuseum.org/art/collection/search/1    1979.0
# 1       http://www.metmuseum.org/art/collection/search/12    1979.0
# 2       http://www.metmuseum.org/art/collection/search/15    1916.0
# 3       http://www.metmuseum.org/art/collection/search/16    1916.0
# 4       http://www.metmuseum.org/art/collection/search/17    1916.0
# 5       http://www.metmuseum.org/art/collection/search/18    1916.0
# 6       http://www.metmuseum.org/art/collection/search/19    1916.0
# 7       http://www.metmuseum.org/art/collection/search/20    1916.0
# 8       http://www.metmuseum.org/art/collection/search/21    1916.0
# 9       http://www.metmuseum.org/art/collection/search/22    1916.0
# 10      http://www.metmuseum.org/art/collection/search/23    1916.0
# 11      http://www.metmuseum.org/art/collection/search/24    1916.0
# 12      http://www.metmuseum.org/art/collection/search/25    1916.0
# 13      http://www.metmuseum.org/art/collection/search/26    1916.0
# 14      http://www.metmuseum.org/art/collection/search/27    1916.0
# 15      http://www.metmuseum.org/art/collection/search/28    1916.0
# 16      http://www.metmuseum.org/art/collection/search/29    1916.0
# 17      http://www.metmuseum.org/art/collection/search/30    1916.0
# 18      http://www.metmuseum.org/art/collection/search/31    1916.0
# 19      http://www.metmuseum.org/art/collection/search/32    1909.0
# 20      http://www.metmuseum.org/art/collection/search/33    1964.0
# 21      http://www.metmuseum.org/art/collection/search/34    1970.0
# 22      http://www.metmuseum.org/art/collection/search/35    1904.0
# 23      http://www.metmuseum.org/art/collection/search/36    1976.0
# 24      http://www.metmuseum.org/art/collection/search/37    1938.0
# 25      http://www.metmuseum.org/art/collection/search/38    1938.0
# 26      http://www.metmuseum.org/art/collection/search/39    1918.0
# 27      http://www.metmuseum.org/art/collection/search/40    1946.0
# 28      http://www.metmuseum.org/art/collection/search/41    1946.0
# 29      http://www.metmuseum.org/art/collection/search/42    1960.0
# ...                                                   ...       ...
# 427562  http://www.metmuseum.org/art/collection/search...    1938.0
# 427563  http://www.metmuseum.org/art/collection/search...    1967.0
# 427564  http://www.metmuseum.org/art/collection/search...    1967.0
# 427565  http://www.metmuseum.org/art/collection/search...    1938.0
# 427566  http://www.metmuseum.org/art/collection/search...    1967.0
# 427567  http://www.metmuseum.org/art/collection/search...    1950.0
# 427568  http://www.metmuseum.org/art/collection/search...    1967.0
# 427569  http://www.metmuseum.org/art/collection/search...    1938.0
# 427570  http://www.metmuseum.org/art/collection/search...    1967.0
# 427571  http://www.metmuseum.org/art/collection/search...    1950.0
# 427572  http://www.metmuseum.org/art/collection/search...    1967.0
# 427573  http://www.metmuseum.org/art/collection/search...    1950.0
# 427574  http://www.metmuseum.org/art/collection/search...    1967.0
# 427575  http://www.metmuseum.org/art/collection/search...    1967.0
# 427576  http://www.metmuseum.org/art/collection/search...    1967.0
# 427577  http://www.metmuseum.org/art/collection/search...    1926.0
# 427578  http://www.metmuseum.org/art/collection/search...    1967.0
# 427579  http://www.metmuseum.org/art/collection/search...    1958.0
# 427580  http://www.metmuseum.org/art/collection/search...    1958.0
# 427581  http://www.metmuseum.org/art/collection/search...    1950.0
# 427582  http://www.metmuseum.org/art/collection/search...    1958.0
# 427583  http://www.metmuseum.org/art/collection/search...    1958.0
# 427584  http://www.metmuseum.org/art/collection/search...    1958.0
# 427585  http://www.metmuseum.org/art/collection/search...    1958.0
# 427586  http://www.metmuseum.org/art/collection/search...    1958.0
# 427587  http://www.metmuseum.org/art/collection/search...    1958.0
# 427588  http://www.metmuseum.org/art/collection/search...    1958.0
# 427589  http://www.metmuseum.org/art/collection/search...    1926.0
# 427590  http://www.metmuseum.org/art/collection/search...    1926.0
# 427591  http://www.metmuseum.org/art/collection/search...    1874.0
#
#        Class_General  region          class         medium  Cluster_ID  \
# 0              Metal     NaN          metal           gold          -1
# 1              Metal     NaN          metal           gold          -1
# 2             Silver     NaN         silver         silver          -1
# 3              Metal     NaN          metal         bronze          -1
# 4              Metal     NaN          metal         bronze          -1
# 5              Metal     NaN          metal         bronze          -1
# 6              Metal     NaN          metal         bronze          -1
# 7              Metal     NaN          metal         bronze          -1
# 8              Metal     NaN          metal         bronze          -1
# 9             Silver     NaN         silver         silver          -1
# 10            Silver     NaN         silver         silver          -1
# 11             Metal     NaN          metal  unknown_other          -1
# 12             Metal     NaN          metal  unknown_other          -1
# 13             Metal     NaN          metal  unknown_other          -1
# 14             Metal     NaN          metal  unknown_other          -1
# 15             Metal     NaN          metal  unknown_other          -1
# 16             Metal     NaN          metal  unknown_other          -1
# 17             Metal     NaN          metal  unknown_other          -1
# 18             Metal     NaN          metal  unknown_other          -1
# 19             Metal     NaN          metal           gold          -1
# 20             Glass     NaN          glass          glass           0
# 21         Furniture     NaN      furniture  unknown_other          -1
# 22             Metal     NaN          metal           gold          -1
# 23         Furniture     NaN      furniture  unknown_other          -1
# 24          Ceramics  Europe       ceramics    earthenware          -1
# 25          Ceramics  Europe       ceramics    earthenware          -1
# 26               NaN     NaN  unknown_other          paper          -1
# 27             Glass     NaN          glass          glass           0
# 28             Glass     NaN          glass          glass           0
# 29             Metal     NaN          metal  unknown_other          -1
# ...              ...     ...            ...            ...         ...
# 427562        Prints  Europe         prints  unknown_other          -1
# 427563        Prints     NaN         prints           etch          38
# 427564        Prints     NaN         prints           etch          38
# 427565        Prints  Europe         prints  unknown_other          -1
# 427566        Prints     NaN         prints           etch          38
# 427567        Prints  Europe         prints         engrav          26
# 427568        Prints     NaN         prints           etch          38
# 427569        Prints  Europe         prints         engrav          26
# 427570        Prints     NaN         prints           etch          38
# 427571        Prints  Europe         prints        colored          -1
# 427572        Prints     NaN         prints           etch          38
# 427573        Prints  Europe         prints           etch          19
# 427574        Prints     NaN         prints           etch          38
# 427575        Prints     NaN         prints           etch          38
# 427576        Prints     NaN         prints           etch          38
# 427577        Prints  Europe         prints         engrav          26
# 427578        Prints     NaN         prints           etch          38
# 427579      Drawings  Europe       drawings            ink          11
# 427580      Drawings  Europe       drawings            ink          11
# 427581        Prints  Europe         prints        colored          -1
# 427582      Drawings  Europe       drawings            ink          11
# 427583      Drawings  Europe       drawings            ink          11
# 427584      Drawings  Europe       drawings            ink          11
# 427585      Drawings  Europe       drawings            ink          11
# 427586      Drawings  Europe       drawings            ink          11
# 427587      Drawings  Europe       drawings            ink          11
# 427588      Drawings  Europe       drawings            ink          11
# 427589        Prints  Europe         prints           etch          19
# 427590        Prints     NaN         prints           etch          38
# 427591        Silver    Asia         silver           gold          -1
#
#         clusterIDs
# 0               -1
# 1               -1
# 2                0
# 3               -1
# 4               -1
# 5               -1
# 6               -1
# 7               -1
# 8               -1
# 9                0
# 10               0
# 11              -1
# 12              -1
# 13              -1
# 14              -1
# 15              -1
# 16              -1
# 17              -1
# 18              -1
# 19              -1
# 20               1
# 21               2
# 22              -1
# 23              -1
# 24              -1
# 25              -1
# 26              -1
# 27               1
# 28               1
# 29              -1
# ...            ...
# 427562         169
# 427563         303
# 427564         303
# 427565         169
# 427566         303
# 427567         279
# 427568         303
# 427569         279
# 427570         303
# 427571          89
# 427572         303
# 427573         334
# 427574         303
# 427575         303
# 427576         303
# 427577         309
# 427578         303
# 427579          60
# 427580          60
# 427581          89
# 427582          60
# 427583          60
# 427584          60
# 427585          60
# 427586          60
# 427587          60
# 427588          60
# 427589         303
# 427590         303
# 427591         249
#
# [427592 rows x 20 columns]

# %%
df.to_sql('Final_Data', engine)

# %%
################################################################################
# TEST QUERY
####################################################################

test = pd.read_sql("SELECT * FROM Final_Data LIMIT 5", con = engine)
print(test)

# %%
specific_test = pd.read_sql("SELECT * FROM Final_Data WHERE `Class_General` = 'Prints'", con = engine)

print(specific_test.head(5))

# %%
# check column names for problems

list (df)

# %%
# select only necessary columns
df_1 = df[['Object ID', 'class', 'medium']]
print(df_1.head(5))

# %%
df_1.columns = ['ID', 'class', 'new_medium']

# %%
# df1 = df.head(1000)

df.to_sql('Final_Data', engine)

# %%
max_class = pd.read_sql("SELECT MAX(COUNT(*)) from Final_Data GROUP BY `Class_General`", con = engine)
print(max_class)

# %%
bubble = pd.read_sql("SELECT `region`, `country`, Count(*) AS count_value FROM Final_Data Group by `region`, `country`", con = engine)
print("bubble: ", bubble)

# %%
bubble_print = pd.read_sql("SELECT `region`, `country`, Count(*) AS count_value FROM Final_Data WHERE `Class_General` = 'Prints' Group by `region`, `country`", con = engine)
print("bubble_print: ", bubble_print)

# %%
all_data = pd.read_sql("Select * FROM Final_Data LIMIT 10", con = engine)
print(all_data)

# %%
bubble = pd.read_sql('SELECT `region`, `country`, Count(*) AS count_value FROM Final_Data Group by `region`, `country` ', con = engine)
print(bubble.head(10))

# %%
distinct = pd.read_sql('SELECT DISTINCT `region` FROM Final_Data', con = engine)

# %%
test = pd.read_sql('SELECT * FROM Final_Data LIMIT 2 ', con = engine)
print(test)

# %%
# summary
summary = pd.read_sql('SELECT `Class_General`, `object_begin_date`, Count(*) AS count_value FROM Final_Data GROUP BY `Class_General`, `object_begin_date` ', con = engine)
print(summary.head(100))

# %%
# subset
subset = pd.read_sql("SELECT * FROM Final_Data WHERE country = 'United States'", con = engine)
print(subset.head(10))

# %%
timeseries = pd.read_sql("SELECT `country`, `acq_year`, COUNT(*) as count FROM Final_Data WHERE country IS NOT NULL AND acq_year IS NOT NULL GROUP BY country, acq_year ORDER BY country, acq_year", con = engine)
print(timeseries.head(10))

# %%
years = pd.read_sql("SELECT * FROM years", con = engine)
print(years)

# %%
timeseries = pd.read_sql("SELECT `country`, `acq_year`, COUNT(*) as count FROM Final_Data GROUP BY country, acq_year ORDER BY country, acq_year", con = engine)
print(timeseries.head(10))

# %%
table_donation = pd.read_sql("SELECT * FROM table_donation LIMIT 10", con = engine)
print(table_donation)

# %%
donation = pd.read_sql("SELECT * FROM donation_data", con = engine)
print(donation)

# %%
countries_count = pd.read_sql("SELECT COUNT(DISTINCT country) FROM Final_Data", con = engine)
print(countries_count)

# %%
join_test = pd.read_sql("SELECT MIN(acq_year FROM final_data)", con = engine)
print(join_test.head(10))

# %%
table_sizes = pd.read_sql("SELECT table_schema as `Database`, table_name AS `Table`, round(((data_length + index_length) / 1024 / 1024), 2) `Size in MB` FROM information_schema.TABLES ORDER BY (data_length + index_length) DESC", con = engine)

# %%
table_sizes['Size in MB'].sum()
