# %%
import pandas as pd
import numpy as np
import pymysql 
import sqlalchemy

# %%
# import the SQLAlchemy libraries
from sqlalchemy import create_engine

# create the connection string to the MySQL database
engine = create_engine('mysql+pymysql://ucfnjma:jucahedagu@dev.spatialdatacapture.org:3306/ucfnjma')

# make the connection to the database
conn = engine.raw_connection()

# %%
#test engine
engine
# Out:
# Engine(mysql+pymysql://ucfnjma:***@dev.spatialdatacapture.org:3306/ucfnjma)

# %%
#test connection
conn

# %%
########
# To upload a dataframe
#########


#Change fileName with the .csv file you want to read into python
# df = pd.read_csv('ClusterData2.csv')
# df.replace(r'\s+', np.nan, regex=True)

#Change SQL_Table_Name for the name of your newly created table

# %%
# check column names
list(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7cc460c49ef5> in <module>()
#       1 # check column names
# ----> 2 list(df)
#
# NameError: name 'df' is not defined

# %%
# select only necessary columns
df_1 = df[['Object ID', 'class', 'medium']]
print(df_1.head(5))

# %%
# df1 = df.head(1000)

df_1.to_sql('Cluster_keys', engine)

# %%
table_names = engine.table_names()
print(table_names)

# %%
################################################################################
# TEST QUERY
####################################################################

test = pd.read_sql("SELECT * FROM Final_Data LIMIT 50", con = engine)
print(test)
# Out:
#     index  Object ID artist_nationality  object_begin_date  object_end_date  \
# 0       0          1           American               1853             1853
# 1       1         12           American               1876             1876
# 2       2         15               None               1665             1700
# 3       3         16               None               1800             1900
# 4       4         17               None               1867             1867
# 5       5         18               None               1860             1860
# 6       6         19               None               1859             1859
# 7       7         20               None               1860             1860
# 8       8         21               None               1859             1859
# 9       9         22               None               1881             1881
# 10     10         23               None               1878             1878
# 11     11         24               None               1860             1870
# 12     12         25               None               1860             1870
# 13     13         26               None               1860             1870
# 14     14         27               None               1860             1870
# 15     15         28               None               1860             1870
# 16     16         29               None               1860             1870
# 17     17         30               None               1885             1885
# 18     18         31               None               1885             1885
# 19     19         32               None               1866             1866
# 20     20         33           American               1876             1876
# 21     21         34               None               1847             1850
# 22     22         35               None               1893             1895
# 23     23         36               None               1884             1887
# 24     24         37             French               1782             1785
# 25     25         38             French               1782             1785
# 26     26         39               None               1770             1800
# 27     27         40               None               1830             1870
# 28     28         41           American               1850             1870
# 29     29         42               None               1795             1810
# 30     30         43               None               1795             1810
# 31     31         64               None               1795             1810
# 32     32         65               None               1795             1810
# 33     33         72               None               1750             1780
# 34     34         73               None               1750             1780
# 35     35         78               None               1697             1700
# 36     36         79               None               1697             1700
# 37     37         80               None               1760             1780
# 38     38         92               None               1795             1815
# 39     39         93               None               1795             1815
# 40     40        100               None               1700             1800
# 41     41        101               None               1700             1800
# 42     42        106               None               1797             1800
# 43     43        107               None               1797             1800
# 44     44        108           American               1792             1814
# 45     45        109           American               1792             1814
# 46     46        110               None               1803             1828
# 47     47        111               None               1803             1828
# 48     48        112               None               1807             1810
# 49     49        113               None               1807             1810
#
#                                           credit_line         country  \
# 0                  Gift of Heinz L. Stoppelmann, 1979   United States
# 1                  Gift of Heinz L. Stoppelmann, 1979   United States
# 2                     Gift of Mrs. Russell Sage, 1916          Mexico
# 7                Metal                                   Bronze or copper
# 8                Metal                                   Bronze or copper
# 9               Silver                                             Silver
# 10              Silver                                             Silver
# 11               Metal                                             Nickel
# 12               Metal                                             Nickel
# 13               Metal                                             Nickel
# 14               Metal                                             Nickel
# 15               Metal                                             Nickel
# 16               Metal                                             Nickel
# 17               Metal                                             Nickel
# 18               Metal                                             Nickel
# 19               Metal                                               Gold
# 20               Glass                                      Pressed glass
# 21           Furniture                                Mahogany, laminated
# 22               Metal  Gold, amethysts, spessartites, tourmalines, fr...
# 23           Furniture                                  Oak, tulip poplar
# 24            Ceramics                                Earthenware, basalt
# 25            Ceramics                                Earthenware, basalt
# 26  Natural Substances                                              Paper
# 27               Glass                                      Pressed glass
# 28               Glass                                      Pressed glass
# 29               Metal                                        Brass, iron
# 30               Metal                                        Brass, iron
# 31               Metal                                        Brass, iron
# 32               Metal                                        Brass, iron
# 33               Metal                                        Brass, iron
# 34               Metal                                        Brass, iron
# 35               Metal                                        Brass, iron
# 36               Metal                                        Brass, iron
# 37               Metal                                        Brass, iron
# 38               Metal                                        Brass, iron
# 39               Metal                                        Brass, iron
# 40               Metal                                               Iron
# 41               Metal                                               Iron
# 42               Metal                                              Brass
# 43               Metal                                              Brass
# 44               Metal                                     Brass and iron
# 45               Metal                                     Brass and iron
# 46               Metal                                              Brass
# 47               Metal                                              Brass
# 48               Metal                                        Brass, iron
# 49               Metal                                        Brass, iron
#
#                   artist_display_name    artist_display_bio  \
# 0               James Barton Longacre              American
# 1               James Barton Longacre              American
# 2                                None                  None
# 3                      Mexican Artist                  None
# 4                      Mexican Artist                  None
# 5                      Mexican Artist                  None
# 6                                None                  None
# 7                                None                  None
# 8                                None                  None
# 9                                None                  None
# 10                               None                  None
# 11                               None                  None
# 12                               None                  None
# 13                               None                  None
# 14                               None                  None
# 15                               None                  None
# 16                               None                  None
# 17                               None                  None
# 18                               None                  None
# 19                     Mexican Artist                  None
# 20           James Gillinder and Sons              American
# 21  Forestville Manufacturing Company             1835–1853
# 22     Paulding Farnham|Tiffany & Co.             1859–1927
# 23                   Conrad Henninger  active ca. 1888–1932
# 24                     Pierre Stephan                French
# 25                     Pierre Stephan                French
# 26                               None                  None
# 27          New England Glass Company              American
# 28                Union Glass Company              American
# 29                               None                  None
# 30                               None                  None
# 31                               None                  None
# 32                               None                  None
# 33                               None                  None
# 34                               None                  None
# 35                               None                  None
# 36                               None                  None
# 37                               None                  None
# 38                               None                  None
# 39                               None                  None
# 40                               None                  None
# 41                               None                  None
# 42                               None                  None
# 43                               None                  None
# 44                        John Bailey              American
# 45                        John Bailey              American
# 46                        James Davis        active 1803–28
# 47                        James Davis        active 1803–28
# 48                      John Molineux  active ca. 1800–1820
# 49                      John Molineux  active ca. 1800–1820
#
#                 culture    object_name  \
# 0                  None           Coin
# 1                  None           Coin
# 2               Mexican           Coin
# 3               Mexican           Peso
# 4               Mexican           Peso
# 5               Mexican           Peso
# 6               Mexican           Peso
# 7               Mexican           Peso
# 8               Mexican           Peso
# 15  unknown_other
# 16  unknown_other
# 17  unknown_other
# 18  unknown_other
# 19           gold
# 20          glass
# 21  unknown_other
# 22           gold
# 23  unknown_other
# 24    earthenware
# 25    earthenware
# 26          paper
# 27          glass
# 28          glass
# 29  unknown_other
# 30  unknown_other
# 31  unknown_other
# 32  unknown_other
# 33  unknown_other
# 34  unknown_other
# 35  unknown_other
# 36  unknown_other
# 37  unknown_other
# 38  unknown_other
# 39  unknown_other
# 40  unknown_other
# 41  unknown_other
# 42  unknown_other
# 43  unknown_other
# 44  unknown_other
# 45  unknown_other
# 46  unknown_other
# 47  unknown_other
# 48  unknown_other
# 49  unknown_other

# %%
max_class = pd.read_sql("SELECT MAX(COUNT(*)) from Final_Data GROUP BY `Class_General`", con = engine)
print(max_class)

# %%
bubble = pd.read_sql("SELECT `region`, `country`, Count(*) AS count_value FROM Final_Data Group by `region`, `country`", con = engine)
print("bubble: ", bubble)

# %%
bubble_print = pd.read_sql("SELECT `region`, `country`, Count(*) AS count_value FROM Final_Data WHERE `Class_General` = 'Prints' Group by `region`, `country`", con = engine)
print("bubble_print: ", bubble_print)

# %%
all_data = pd.read_sql("Select * FROM Final_Data LIMIT 10", con = engine)
print(all_data)

# %%
bubble = pd.read_sql('SELECT `region`, `country`, Count(*) AS count_value FROM Final_Data Group by `region`, `country` ', con = engine)
print(bubble.head(10))

# %%
distinct = pd.read_sql('SELECT DISTINCT `region` FROM Final_Data', con = engine)

# %%
test = pd.read_sql('SELECT * FROM Final_Data LIMIT 2 ', con = engine)
print(test)

# %%
# summary
summary = pd.read_sql('SELECT `Class_General`, `object_begin_date`, Count(*) AS count_value FROM Final_Data GROUP BY `Class_General`, `object_begin_date` ', con = engine)
print(summary.head(100))

# %%
# subset
subset = pd.read_sql("SELECT * FROM Final_Data WHERE country = 'United States'", con = engine)
print(subset.head(10))

# %%
timeseries = pd.read_sql("SELECT `country`, `acq_year`, COUNT(*) as count FROM Final_Data WHERE country IS NOT NULL AND acq_year IS NOT NULL GROUP BY country, acq_year ORDER BY country, acq_year", con = engine)
print(timeseries.head(10))

# %%
years = pd.read_sql("SELECT * FROM years", con = engine)
print(years)

# %%
timeseries = pd.read_sql("SELECT `country`, `acq_year`, COUNT(*) as count FROM Final_Data GROUP BY country, acq_year ORDER BY country, acq_year", con = engine)
print(timeseries.head(10))

# %%
table_donation = pd.read_sql("SELECT * FROM table_donation LIMIT 10", con = engine)
print(table_donation)

# %%
donation = pd.read_sql("SELECT * FROM donation_data", con = engine)
print(donation)

# %%
countries_count = pd.read_sql("SELECT COUNT(DISTINCT country) FROM Final_Data", con = engine)
print(countries_count)

# %%
join_test = pd.read_sql("SELECT MIN(acq_year FROM final_data)", con = engine)
print(join_test.head(10))

# %%
table_sizes = pd.read_sql("SELECT table_schema as `Database`, table_name AS `Table`, round(((data_length + index_length) / 1024 / 1024), 2) `Size in MB` FROM information_schema.TABLES ORDER BY (data_length + index_length) DESC", con = engine)

# %%
table_sizes['Size in MB'].sum()
