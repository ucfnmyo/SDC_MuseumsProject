# %%
import pandas as pd
import numpy as np
import pymysql 
import sqlalchemy

# %%
# import the SQLAlchemy libraries
from sqlalchemy import create_engine

# create the connection string to the MySQL database
engine = create_engine('mysql+pymysql://ucfnjma:jucahedagu@dev.spatialdatacapture.org:3306/ucfnjma')

# make the connection to the database
conn = engine.raw_connection()

# %%
#test engine
engine
# Out:
# Engine(mysql+pymysql://ucfnjma:***@dev.spatialdatacapture.org:3306/ucfnjma)

# %%
#test connection
conn

# %%
########
# To upload a dataframe
#########


#Change fileName with the .csv file you want to read into python
df = pd.read_csv('ClusterData2.csv')
df.replace(r'\s+', np.nan, regex=True)

#Change SQL_Table_Name for the name of your newly created table
# Out:
#         Unnamed: 0  Unnamed: 0.1  Object ID   age    country          class  \
# 0                0             0          1  1853        NaN          metal
# 1                1             1         12  1876        NaN          metal
# 2                2             2         15  1665     Mexico         silver
# 3                3             3         16  1800     Mexico          metal
# 4                4             4         17  1867     Mexico          metal
# 5                5             5         18  1860     Mexico          metal
# 6                6             6         19  1859     Mexico          metal
# 7                7             7         20  1860     Mexico          metal
# 8                8             8         21  1859     Mexico          metal
# 9                9             9         22  1881  Guatemala         silver
# 10              10            10         23  1878  Guatemala         silver
# 11              11            11         24  1860     Mexico          metal
# 12              12            12         25  1860     Mexico          metal
# 13              13            13         26  1860     Mexico          metal
# 14              14            14         27  1860     Mexico          metal
# 15              15            15         28  1860     Mexico          metal
# 16              16            16         29  1860     Mexico          metal
# 17              17            17         30  1885     Mexico          metal
# 18              18            18         31  1885     Mexico          metal
# 19              19            19         32  1866     Mexico          metal
# 20              20            20         33  1876        NaN          glass
# 21              21            21         34  1847        NaN      furniture
# 22              22            22         35  1893        NaN          metal
# 23              23            23         36  1884        NaN      furniture
# 24              24            24         37  1782        NaN       ceramics
# 25              25            25         38  1782        NaN       ceramics
# 26              26            26         39  1770        NaN  unknown/other
# 27              27            27         40  1830        NaN          glass
# 28              28            28         41  1850        NaN          glass
# 29              29            29         42  1795        NaN          metal
# ...            ...           ...        ...   ...        ...            ...
# 427562      427562        427562     825635  1821     France         prints
# 427563      427563        427563     825646  1860        NaN         prints
# 427564      427564        427564     825676  1886        NaN         prints
# 427565      427565        427565     825677  1826        NaN         prints
# 427566      427566        427566     825678  1875        NaN         prints
# 427567      427567        427567     825679  1830     France         prints
# 427568      427568        427568     825680  1875        NaN         prints
# 427569      427569        427569     825681  1821     France         prints
# 427570      427570        427570     825682  1880        NaN         prints
# 427571      427571        427571     825684  1838     France         prints
# 427572      427572        427572     825685  1875        NaN         prints
# 427573      427573        427573     825728  1800     France         prints
# 427574      427574        427574     825729  1878        NaN         prints
# 427575      427575        427575     825730  1875        NaN         prints
# 427576      427576        427576     825731  1873        NaN         prints
# 427577      427577        427577     825732  1793     France         prints
# 427578      427578        427578     825733  1875        NaN         prints
# 427579      427579        427579     825735  1830        NaN       drawings
# 427580      427580        427580     825736  1830        NaN       drawings
# 427581      427581        427581     825737  1796     France         prints
# 427582      427582        427582     825738  1830        NaN       drawings
# 427583      427583        427583     825739  1830        NaN       drawings
# 427584      427584        427584     825740  1830        NaN       drawings
# 427585      427585        427585     825741  1830        NaN       drawings
# 427586      427586        427586     825742  1830        NaN       drawings
# 427587      427587        427587     825743  1830        NaN       drawings
# 427588      427588        427588     825745  1830        NaN       drawings
# 427589      427589        427589     825746  1794        NaN         prints
# 427590      427590        427590     825747  1796        NaN         prints
# 427591      427591        427591     825751 -1600     Cyprus         silver
#
#                medium        coordX        coordY  prints  ...   film  chalk  \
# 0                gold -1.198170e+06  7.068348e+05       0  ...    NaN    NaN
# 1                gold -1.198170e+06  7.068348e+05       0  ...    NaN    NaN
# 2              silver -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 3              bronze -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 4              bronze -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 5              bronze -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 6              bronze -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 7              bronze -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 8              bronze -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 9              silver  6.215356e+05 -2.591948e+06       0  ...    NaN    NaN
# 10             silver  6.215356e+05 -2.591948e+06       0  ...    NaN    NaN
# 11      unknown/other -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 12      unknown/other -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 13      unknown/other -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 14      unknown/other -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 15      unknown/other -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 16      unknown/other -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 17      unknown/other -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 18      unknown/other -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 19               gold -6.499305e+05 -1.672995e+06       0  ...    NaN    NaN
# 20              glass -1.198170e+06  7.068348e+05       0  ...    NaN    NaN
# 21      unknown/other -1.198170e+06  7.068348e+05       0  ...    NaN    NaN
# 22               gold -1.198170e+06  7.068348e+05       0  ...    NaN    NaN
# 23      unknown/other -1.198170e+06  7.068348e+05       0  ...    NaN    NaN
# 24        earthenware  4.837879e+06  4.351821e+06       0  ...    NaN    NaN
# 25        earthenware  4.837879e+06  4.351821e+06       0  ...    NaN    NaN
# 26              paper -1.198170e+06  7.068348e+05       0  ...    NaN    NaN
# 27              glass -1.198170e+06  7.068348e+05       0  ...    NaN    NaN
# 28              glass -1.198170e+06  7.068348e+05       0  ...    NaN    NaN
# 29      unknown/other -1.198170e+06  7.068348e+05       0  ...    NaN    NaN
# ...               ...           ...           ...     ...  ...    ...    ...
# 427562  unknown/other  5.707514e+06  4.304454e+06       1  ...    NaN    NaN
# 427563           etch -1.198170e+06  7.068348e+05       1  ...    NaN    NaN
# 427564           etch -1.198170e+06  7.068348e+05       1  ...    NaN    NaN
# 427565  unknown/other  4.837879e+06  4.351821e+06       1  ...    NaN    NaN
# 427566           etch -1.198170e+06  7.068348e+05       1  ...    NaN    NaN
# 427567         engrav  5.707514e+06  4.304454e+06       1  ...    NaN    NaN
# 427568           etch -1.198170e+06  7.068348e+05       1  ...    NaN    NaN
# 427569         engrav  5.707514e+06  4.304454e+06       1  ...    NaN    NaN
# 427570           etch -1.198170e+06  7.068348e+05       1  ...    NaN    NaN
# 427571        colored  5.707514e+06  4.304454e+06       1  ...    NaN    NaN
# 427572           etch -1.198170e+06  7.068348e+05       1  ...    NaN    NaN
# 427573           etch  5.707514e+06  4.304454e+06       1  ...    NaN    NaN
# 427574           etch -1.198170e+06  7.068348e+05       1  ...    NaN    NaN
# 427575           etch -1.198170e+06  7.068348e+05       1  ...    NaN    NaN
# 427576           etch -1.198170e+06  7.068348e+05       1  ...    NaN    NaN
# 427577         engrav  5.707514e+06  4.304454e+06       1  ...    NaN    NaN
# 427578           etch -1.198170e+06  7.068348e+05       1  ...    NaN    NaN
# 427579            ink  4.837879e+06  4.351821e+06       0  ...    NaN    NaN
# 427580            ink  4.837879e+06  4.351821e+06       0  ...    NaN    NaN
# 427581        colored  5.707514e+06  4.304454e+06       1  ...    NaN    NaN
# 427582            ink  4.837879e+06  4.351821e+06       0  ...    NaN    NaN
# 427583            ink  4.837879e+06  4.351821e+06       0  ...    NaN    NaN
# 427584            ink  4.837879e+06  4.351821e+06       0  ...    NaN    NaN
# 427585            ink  4.837879e+06  4.351821e+06       0  ...    NaN    NaN
# 427586            ink  4.837879e+06  4.351821e+06       0  ...    NaN    NaN
# 427587            ink  4.837879e+06  4.351821e+06       0  ...    NaN    NaN
# 427588            ink  4.837879e+06  4.351821e+06       0  ...    NaN    NaN
# 427589           etch  4.837879e+06  4.351821e+06       1  ...    NaN    NaN
# 427590           etch -1.198170e+06  7.068348e+05       1  ...    NaN    NaN
# 427591           gold  7.483808e+06  6.328037e+06       0  ...    NaN    NaN
#
#         polychrome  gouache  tint  cotton  linen  gilt  thread  wool
# 0              NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 1              NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 2              NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 3              NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 4              NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 5              NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 6              NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 7              NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 8              NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 9              NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 10             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 11             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 12             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 13             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 14             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 15             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 16             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 17             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 18             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 19             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 20             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 21             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 22             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 23             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 24             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 25             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 26             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 27             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 28             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 29             NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# ...            ...      ...   ...     ...    ...   ...     ...   ...
# 427562         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427563         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427564         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427565         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427566         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427567         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427568         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427569         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427570         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427571         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427572         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427573         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427574         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427575         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427576         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427577         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427578         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427579         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427580         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427581         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427582         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427583         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427584         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427585         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427586         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427587         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427588         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427589         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427590         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 427591         NaN      NaN   NaN     NaN    NaN   NaN     NaN   NaN
#
# [427592 rows x 86 columns]

# %%
# check column names
list(df)
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0.1',
#  'Object ID',
#  'age',
#  'country',
#  'class',
#  'medium',
#  'coordX',
#  'coordY',
#  'prints',
#  'photographs',
#  'drawings',
#  'textiles',
#  'ceramics',
#  'vases',
#  'books',
#  'paintings',
#  'metalwork',
#  'glass_x',
#  'sculpture',
#  'negatives',
#  'wood_x',
#  'sword',
#  'stone_x',
#  '|',
#  'silver_x',
#  'ornament',
#  'medals',
#  'woodwork',
#  'jewelry',
#  'ornaments',
#  'miscellaneous',
#  'furniture',
#  'stucco',
#  'aerophone',
#  'metal_x',
#  'gems',
#  'terracottas',
#  'jade',
#  'codices',
#  'bronzes',
#  'armor',
#  'chordophone',
#  'albums',
#  'idiophone',
#  'coins',
#  'etch',
#  'print',
#  'silver_y',
#  'ink',
#  'engrav',
#  'paper',
#  'wood_y',
#  'terracotta',
#  'tin',
#  'silk',
#  'glass_y',
#  'photo',
#  'glaze',
#  'graphite',
#  'gold',
#  'porcelain',
#  'gelatin',
#  'brown',
#  'bronze',
#  'ash',
#  'paste',
#  'woodcut',
#  'paint',
#  'line',
#  'earthenware',
#  'stone_y',
#  'metal_y',
#  'oil',
#  'copper',
#  'colored',
#  'film',
#  'chalk',
#  'polychrome',
#  'gouache',
#  'tint',
#  'cotton',
#  'linen',
#  'gilt',
#  'thread',
#  'wool']

# %%
# select only necessary columns
df_1 = df[['Object ID', 'class', 'medium']]
print(df_1.head(5))
# Out:
#    Object ID   class  medium
# 0          1   metal    gold
# 1         12   metal    gold
# 2         15  silver  silver
# 3         16   metal  bronze
# 4         17   metal  bronze

# %%
# df1 = df.head(1000)

df_1.to_sql('Cluster_keys', engine)

# %%
table_names = engine.table_names()
print(table_names)
# Out:
# ['Cluster_Table', 'Cluster_keys', 'Final_Data', 'METDataClean', 'MET_Final', 'MET_Final2', 'MET_USA_clean_spatial4', 'Met430k', 'MetCountry(clustered)', 'Met_noUSA', 'SpatialMET', 'SpatialMET_test', 'artwork_cities', 'artwork_cities_final', 'cities', 'countries', 'countries_donation', 'countries_for_join', 'countries_years', 'countries_years_good', 'donation_data', 'final_donation', 'materials', 'metadata', 'table_donation', 'table_donation_good', 'worldCities', 'years']

# %%
test = pd.read_sql("SELECT * FROM Final_Data LIMIT 5", con = engine)
print(test)
# Out:
#    index  Unnamed: 0  Object ID artist_nationality  object_begin_date  \
# 0      0           0          1           American               1853
# 1      1           1         12           American               1876
# 2      2           2         15               None               1665
# 3      3           3         16               None               1800
# 4      4           4         17               None               1867
#
#    object_end_date                         credit_line        country  \
# 0             1853  Gift of Heinz L. Stoppelmann, 1979  United States
# 1             1876  Gift of Heinz L. Stoppelmann, 1979  United States
# 2             1700     Gift of Mrs. Russell Sage, 1916         Mexico
# 3             1900     Gift of Mrs. Russell Sage, 1916         Mexico
# 4             1867     Gift of Mrs. Russell Sage, 1916         Mexico
#
#   classification            medium    artist_display_name artist_display_bio  \
# 0          Metal              Gold  James Barton Longacre           American
# 1          Metal              Gold  James Barton Longacre           American
# 2         Silver            Silver                   None               None
# 3          Metal  Bronze or copper         Mexican Artist               None
# 4          Metal  Bronze or copper         Mexican Artist               None
#
#    culture object_name                                               link  \
# 0     None        Coin   http://www.metmuseum.org/art/collection/search/1
# 1     None        Coin  http://www.metmuseum.org/art/collection/search/12
# 2  Mexican        Coin  http://www.metmuseum.org/art/collection/search/15
# 3  Mexican        Peso  http://www.metmuseum.org/art/collection/search/16
# 4  Mexican        Peso  http://www.metmuseum.org/art/collection/search/17
#
#    acq_year Class_General         region
# 0    1979.0         Metal  North America
# 1    1979.0         Metal  North America
# 2    1916.0        Silver  Latin America
# 3    1916.0         Metal  Latin America
# 4    1916.0         Metal  Latin America

# %%
max_class = pd.read_sql("SELECT MAX(COUNT(*)) from Final_Data GROUP BY `Class_General`", con = engine)
print(max_class)

# %%
bubble = pd.read_sql("SELECT `region`, `country`, Count(*) AS count_value FROM Final_Data Group by `region`, `country`", con = engine)
print("bubble: ", bubble)

# %%
bubble_print = pd.read_sql("SELECT `region`, `country`, Count(*) AS count_value FROM Final_Data WHERE `Class_General` = 'Prints' Group by `region`, `country`", con = engine)
print("bubble_print: ", bubble_print)

# %%
all_data = pd.read_sql("Select * FROM Final_Data LIMIT 10", con = engine)
print(all_data)

# %%
bubble = pd.read_sql('SELECT `region`, `country`, Count(*) AS count_value FROM Final_Data Group by `region`, `country` ', con = engine)
print(bubble.head(10))

# %%
distinct = pd.read_sql('SELECT DISTINCT `region` FROM Final_Data', con = engine)

# %%
test = pd.read_sql('SELECT * FROM Final_Data LIMIT 2 ', con = engine)
print(test)

# %%
# summary
summary = pd.read_sql('SELECT `Class_General`, `object_begin_date`, Count(*) AS count_value FROM Final_Data GROUP BY `Class_General`, `object_begin_date` ', con = engine)
print(summary.head(100))

# %%
# subset
subset = pd.read_sql("SELECT * FROM Final_Data WHERE country = 'United States'", con = engine)
print(subset.head(10))

# %%
timeseries = pd.read_sql("SELECT `country`, `acq_year`, COUNT(*) as count FROM Final_Data WHERE country IS NOT NULL AND acq_year IS NOT NULL GROUP BY country, acq_year ORDER BY country, acq_year", con = engine)
print(timeseries.head(10))

# %%
years = pd.read_sql("SELECT * FROM years", con = engine)
print(years)

# %%
timeseries = pd.read_sql("SELECT `country`, `acq_year`, COUNT(*) as count FROM Final_Data GROUP BY country, acq_year ORDER BY country, acq_year", con = engine)
print(timeseries.head(10))

# %%
table_donation = pd.read_sql("SELECT * FROM table_donation LIMIT 10", con = engine)
print(table_donation)

# %%
donation = pd.read_sql("SELECT * FROM donation_data", con = engine)
print(donation)

# %%
countries_count = pd.read_sql("SELECT COUNT(DISTINCT country) FROM Final_Data", con = engine)
print(countries_count)

# %%
join_test = pd.read_sql("SELECT MIN(acq_year FROM final_data)", con = engine)
print(join_test.head(10))

# %%
table_sizes = pd.read_sql("SELECT table_schema as `Database`, table_name AS `Table`, round(((data_length + index_length) / 1024 / 1024), 2) `Size in MB` FROM information_schema.TABLES ORDER BY (data_length + index_length) DESC", con = engine)

# %%
table_sizes['Size in MB'].sum()
