# %% [markdown]
# Collecting Historical Data from Darwin API

# %%
#Importing libraries
import pandas as pd
import requests
import numpy as np
import json
from pandas.io.json import json_normalize

# %%
#Initialising endpoint

#Service Details endpoint
SD_endpoint = "https://hsp-prod.rockshore.net/api/v1/serviceDetails"

#Service Metrics endpoint
SM_endpoint = "https://hsp-prod.rockshore.net/api/v1/serviceMetrics"

# %% [markdown]
# # Service Metrics - Historical Data Performance

# %%
#Setting Headers and authorisation
header = {"Content-Type" : "application/json"};
auth = ("mohammadyounes08@gmail.com","CASAEliteSquad2019$$");

#Empty Dataframe to append the data to
Services = pd.DataFrame(columns = ["Metrics","serviceAttributesMetrics.destination_location","serviceAttributesMetrics.gbtt_pta","serviceAttributesMetrics.gbtt_ptd","serviceAttributesMetrics.matched_services","serviceAttributesMetrics.origin_location","serviceAttributesMetrics.rids","serviceAttributesMetrics.toc_code"])

#csv file of station codes to loop over
StationCodes = pd.read_csv('station_codes.csv')

for stn1 in StationCodes['CRS Code']:
    
    for stn2 in StationCodes['CRS Code']:
        
      
        if(stn1 != stn2):
            
            data = {'url': SM_endpoint, 
                
                #The request requires an origin station (stn1) and a destination station (stn 2). The time is put from 0000 to 2359 to imply the full day.
                #Make sure to change the dates to get the desired data
                "from_loc": stn1,
                "to_loc": stn2,
                "from_time":"0000",
                "to_time":"2359",
                "from_date":"2016-01-01",
                "to_date":"2016-01-03",
                "days":"WEEKDAY"
        
            }
            
            
            SM_requests = requests.post(SM_endpoint, headers = header, auth = auth, data = json.dumps(data))
            
                
            Data = json_normalize(SM_requests.json()['Services']) 
            
            Services = Services.append(Data, ignore_index = True)
            
            print(stn1, stn2)
# Out:
# ABW ABE
# ABW ACY
# ABW ABA
# ABW ABD
# ABW AUR
# ABW AVY
# ABW ABH
# ABW AGV
# ABW AGL
# ABW AYW
# ABW ACR
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-049abf02fbb3> in <module>
#      31
#      32
# ---> 33             SM_requests = requests.post(SM_endpoint, headers = header, auth = auth, data = json.dumps(data))
#      34
#      35
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
Services
# Out:
# Empty DataFrame
# Columns: [Metrics, serviceAttributesMetrics.destination_location, serviceAttributesMetrics.gbtt_pta, serviceAttributesMetrics.gbtt_ptd, serviceAttributesMetrics.matched_services, serviceAttributesMetrics.origin_location, serviceAttributesMetrics.rids, serviceAttributesMetrics.toc_code]
# Index: []

# %% [markdown]
# # Service Details - Historical Data Service Performance

# %%
#Setting Request details - header and auth

header = {"Content-Type" : "application/json"};
auth = ("mohammadyounes08@gmail.com","CASAEliteSquad2019$$");

#The RIDs obtained from the service metrics API contain the date in the first 8 digits.
#for example 201607294212242 would indicate 29/07/2016

#Empty dataframe to append data from the requests
ServiceDetails = pd.DataFrame(columns = ["date_of_service","locations","rid", "toc_code"])

#This for loop iterates over the rids obtained from the Service metrics request to obtain the details on each train.
#The returned information will include data on schedules arrivals and actual time of arrival

for rid in Services['serviceAttributesMetrics.rids']:
    
    data = {'url': SD_endpoint, "Content-Length":1000, "rid" : rid[0]}
    
    SD_requests = requests.post(SD_endpoint, headers= header, auth=auth, data = json.dumps(data))

    SD_PD = json_normalize(SD_requests.json()['serviceAttributesDetails'])
# 23      2016-01-01  [{'location': 'HNX', 'gbtt_ptd': '1506', 'gbtt...
# 24      2016-01-01  [{'location': 'HNX', 'gbtt_ptd': '1536', 'gbtt...
# 25      2016-01-01  [{'location': 'HNX', 'gbtt_ptd': '1606', 'gbtt...
# 26      2016-01-01  [{'location': 'HNX', 'gbtt_ptd': '1636', 'gbtt...
# 27      2016-01-01  [{'location': 'HNX', 'gbtt_ptd': '1706', 'gbtt...
# 28      2016-01-01  [{'location': 'HNX', 'gbtt_ptd': '1736', 'gbtt...
# 29      2016-01-01  [{'location': 'HNX', 'gbtt_ptd': '1806', 'gbtt...
# ..             ...                                                ...
# 41      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '0828', 'gbtt...
# 42      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '0858', 'gbtt...
# 43      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '0928', 'gbtt...
# 44      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '0958', 'gbtt...
# 45      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1028', 'gbtt...
# 46      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1058', 'gbtt...
# 47      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1128', 'gbtt...
# 48      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1158', 'gbtt...
# 49      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1228', 'gbtt...
# 50      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1258', 'gbtt...
# 51      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1328', 'gbtt...
# 52      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1358', 'gbtt...
# 53      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1428', 'gbtt...
# 54      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1458', 'gbtt...
# 55      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1528', 'gbtt...
# 56      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1558', 'gbtt...
# 57      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1628', 'gbtt...
# 58      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1658', 'gbtt...
# 59      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1728', 'gbtt...
# 60      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1758', 'gbtt...
# 61      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1828', 'gbtt...
# 62      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1858', 'gbtt...
# 63      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1928', 'gbtt...
# 64      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '1958', 'gbtt...
# 65      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '2028', 'gbtt...
# 66      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '2058', 'gbtt...
# 67      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '2128', 'gbtt...
# 68      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '2158', 'gbtt...
# 69      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '2228', 'gbtt...
# 70      2016-01-01  [{'location': 'SOP', 'gbtt_ptd': '2258', 'gbtt...
#
#                 rid toc_code
# 0   201601011282094       AW
# 1   201601011282095       AW
# 2   201601011282096       AW
# 3   201601011282097       AW
# 4   201601011282101       AW
# 5   201601011282102       AW
# 6   201601011274706       AW
# 7   201601011275763       NT
# 8   201601011275754       NT
# 9   201601011282823       ME
# 10  201601011282826       ME
# 11  201601011282829       ME
# 12  201601011282831       ME
# 13  201601011282833       ME
# 14  201601011282835       ME
# 15  201601011283337       ME
# 16  201601011283339       ME
# 17  201601011283341       ME
# 18  201601011283344       ME
# 19  201601011283347       ME
# 20  201601011283350       ME
# 21  201601011282838       ME
# 22  201601011283352       ME
# 23  201601011282840       ME
# 24  201601011282843       ME
# 25  201601011282846       ME
# 26  201601011282848       ME
# 27  201601011282851       ME
# 28  201601011283354       ME
# 29  201601011283357       ME
# ..              ...      ...
# 41  201601011282860       ME
# 42  201601011282863       ME
# 43  201601011282865       ME
# 44  201601011282867       ME
# 45  201601011283391       ME
# 46  201601011283394       ME
# 47  201601011283396       ME
# 48  201601011283399       ME
# 49  201601011283401       ME
# 50  201601011283404       ME
# 51  201601011283407       ME
# 52  201601011283410       ME
# 53  201601011283412       ME
# 54  201601011283415       ME
# 55  201601011283418       ME
# 56  201601011283420       ME
# 57  201601011283423       ME
# 58  201601011283426       ME
# 59  201601011283429       ME
# 60  201601011283431       ME
# 61  201601011283436       ME
# 62  201601011283440       ME
# 63  201601011283442       ME
# 64  201601011283444       ME
# 65  201601011283447       ME
# 66  201601011283450       ME
# 67  201601011283453       ME
# 68  201601011283455       ME
# 69  201601011283457       ME
# 70  201601011283460       ME
#
# [71 rows x 4 columns]
